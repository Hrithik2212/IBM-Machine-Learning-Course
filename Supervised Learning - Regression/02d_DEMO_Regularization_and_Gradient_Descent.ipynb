# %% [markdown]
# # Machine Learning Foundation
#
# ## Section 2, Part d:  Regularization and Gradient Descent

# %% [markdown]
# ## Introduction
#
# We will begin with a short tutorial on regression, polynomial features, and regularization based on a very simple, sparse data set that contains a column of `x` data and associated `y` noisy data. The data file is called `X_Y_Sinusoid_Data.csv`.

# %% [markdown]
# ## Question 1
#
# * Import the data.
#
# * Also generate approximately 100 equally spaced x data points over the range of 0 to 1. Using these points, calculate the y-data which represents the "ground truth" (the real function) from the equation: $y = sin(2\pi x)$
#
# * Plot the sparse data (`x` vs `y`) and the calculated ("real") data.

# %%
import pandas as pd
import numpy as np

filepath ='X_Y_Sinusoid_Data.csv'
data = pd.read_csv(filepath)

X_real = np.linspace(0, 1.0, 100)
Y_real = np.sin(2 * np.pi * X_real)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.set_style('white')
sns.set_context('talk')
sns.set_palette('dark')

# Plot of the noisy (sparse)
ax = data.set_index('x')['y'].plot(ls='', marker='o', label='data')
ax.plot(X_real, Y_real, ls='-', marker='', label='real function')

ax.legend()
ax.set(xlabel='x data', ylabel='y data');

# %% [markdown]
# ## Question 2
#
#
# * Using the `PolynomialFeatures` class from Scikit-learn's preprocessing library, create 20th order polynomial features.
# * Fit this data using linear regression.
# * Plot the resulting predicted value compared to the calculated data.
#
# Note that `PolynomialFeatures` requires either a dataframe (with one column, not a Series) or a 2D array of dimension (`X`, 1), where `X` is the length.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Setup the polynomial features
degree = 20
pf = PolynomialFeatures(degree)
lr = LinearRegression()

# Extract the X- and Y- data from the dataframe 
X_data = data[['x']]
Y_data = data['y']

# Create the features and fit the model
X_poly = pf.fit_transform(X_data)
lr = lr.fit(X_poly, Y_data)
Y_pred = lr.predict(X_poly)

# Plot the result
plt.figure(figsize=(10,10))
plt.plot(X_data, Y_data, marker='o', ls='', label='data', alpha=1)
plt.plot(X_real, Y_real, ls='--', label='real function')
plt.plot(X_data, Y_pred, marker='^', alpha=.8, label='predictions w/ polynomial features')
plt.legend()
ax = plt.gca()
ax.set(xlabel='x data', ylabel='y data');

# %% [markdown]
# ## Question 3
#
# * Perform the regression on using the data with polynomial features using ridge regression ($\alpha$=0.001) and lasso regression ($\alpha$=0.0001).
# * Plot the results, as was done in Question 1.
# * Also plot the magnitude of the coefficients obtained from these regressions, and compare them to those obtained from linear regression in the previous question. The linear regression coefficients will likely need a separate plot (or their own y-axis) due to their large magnitude.
#
# What does the comparatively large magnitude of the data tell you about the role of regularization?

# %%
# # Mute the sklearn warning about regularization
# import warnings
# warnings.filterwarnings('ignore', module='sklearn')

from sklearn.linear_model import Ridge, Lasso

# The ridge regression model
rr = Ridge(alpha=0.001)
rr = rr.fit(X_poly, Y_data)
Y_pred_rr = rr.predict(X_poly)

# The lasso regression model
lassor = Lasso(alpha=0.0001)
lassor = lassor.fit(X_poly, Y_data)
Y_pred_lr = lassor.predict(X_poly)

# The plot of the predicted values
plt.figure(figsize=(10,10))
plt.plot(X_data, Y_data, marker='o', ls='', label='data')
plt.plot(X_real, Y_real, ls='--', label='real function')
plt.plot(X_data, Y_pred, label='linear regression', marker='^', alpha=.5)
plt.plot(X_data, Y_pred_rr, label='ridge regression', marker='^', alpha=.5)
plt.plot(X_data, Y_pred_lr, label='lasso regression', marker='^', alpha=.5)

plt.legend()

ax = plt.gca()
ax.set(xlabel='x data', ylabel='y data');
# Out:
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.470e-01, tolerance: 1.223e-03
#   model = cd_fast.enet_coordinate_descent(

# %%
# let's look at the absolute value of coefficients for each model

coefficients = pd.DataFrame()
coefficients['linear regression'] = lr.coef_.ravel()
coefficients['ridge regression'] = rr.coef_.ravel()
coefficients['lasso regression'] = lassor.coef_.ravel()
coefficients = coefficients.applymap(abs)

coefficients.describe()  # Huge difference in scale between non-regularized vs regularized regression
# Out:
#        linear regression  ridge regression  lasso regression
# count       2.100000e+01         21.000000         21.000000
# mean        5.778976e+13          2.169397          2.167284
# std         5.999043e+13          2.900278          4.706731
# min         1.617719e+07          0.000000          0.000000
# 25%         3.413029e+12          0.467578          0.000000
# 50%         3.636725e+13          1.017272          0.252181
# 75%         1.064041e+14          2.883507          1.641353
# max         1.643246e+14         12.429635         20.176708

# %%
(coefficients>0).sum()
# Out:
# linear regression    21
# ridge regression     20
# lasso regression     15
# dtype: int64

# %%
colors = sns.color_palette()

# Setup the dual y-axes
plt.figure(figsize=(10,10))
ax1 = plt.axes()
ax2 = ax1.twinx()

# Plot the linear regression data
ax1.plot(lr.coef_.ravel(), 
         color=colors[0], marker='o', label='linear regression')

# Plot the regularization data sets
ax2.plot(rr.coef_.ravel(), 
         color=colors[1], marker='o', label='ridge regression')

ax2.plot(lassor.coef_.ravel(), 
         color=colors[2], marker='o', label='lasso regression')

# Customize axes scales
ax1.set_ylim(-2e14, 2e14)
ax2.set_ylim(-25, 25)

# Combine the legends
h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2)

ax1.set(xlabel='coefficients',ylabel='linear regression')
ax2.set(ylabel='ridge and lasso regression')

ax1.set_xticks(range(len(lr.coef_)));

# %% [markdown]
# ## Question 4
#
# For the remaining questions, we will be working with the [data set](https://www.kaggle.com/c/house-prices-advanced-regression-techniques) from last lesson, which is based on housing prices in Ames, Iowa. There are an extensive number of features--see the exercises from week three for a discussion of these features.
#
# To begin:
#
# * Import the data with Pandas, remove any null values, and one hot encode categoricals. Either Scikit-learn's feature encoders or Pandas `get_dummies` method can be used.
# * Split the data into train and test sets.
# * Log transform skewed features.
# * Scaling can be attempted, although it can be interesting to see how well regularization works without scaling features.

# %%
file_path="AHS.csv"

data= pd.read_csv(file_path, sep=',')

# %% [markdown]
# Create a list of categorial data and one-hot encode. Pandas one-hot encoder (`get_dummies`) works well with data that is defined as a categorical.

# %%
# Get a Pd.Series consisting of all the string categoricals
one_hot_encode_cols = data.dtypes[data.dtypes == np.object]  # filtering by string categoricals
one_hot_encode_cols = one_hot_encode_cols.index.tolist()  # list of categorical fields

# Here we see another way of one-hot-encoding:
# Encode these columns as categoricals so one hot encoding works on split data (if desired)
for col in one_hot_encode_cols:
    data[col] = pd.Categorical(data[col])

# Do the one hot encoding
data = pd.get_dummies(data, columns=one_hot_encode_cols)
# Out:
# C:\Users\HRITHI~1\AppData\Local\Temp/ipykernel_11384/541837702.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   one_hot_encode_cols = data.dtypes[data.dtypes == np.object]  # filtering by string categoricals

# %% [markdown]
# Next, split the data in train and test data sets.

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.3, random_state=42)

# %% [markdown]
# There are a number of columns that have skewed features--a log transformation can be applied to them. Note that this includes the `SalePrice`, our predictor. However, let's keep that one as is.

# %%
# Create a list of float colums to check for skewing
mask = data.dtypes == np.float64
float_cols = data.columns[mask]

# %%
skew_limit = 0.75
skew_vals = train[float_cols].skew()

skew_cols = (skew_vals
             .sort_values(ascending=False)
             .to_frame()
             .rename(columns={0:'Skew'})
             .query('abs(Skew) > {0}'.format(skew_limit)))

skew_cols
# Out:
#                     Skew
# MiscVal        26.915364
# PoolArea       15.777668
# LotArea        11.501694
# LowQualFinSF   11.210638
# 3SsnPorch      10.150612
# ScreenPorch     4.599803
# BsmtFinSF2      4.466378
# EnclosedPorch   3.218303
# LotFrontage     3.138032
# MasVnrArea      2.492814
# OpenPorchSF     2.295489
# SalePrice       2.106910
# BsmtFinSF1      2.010766
# TotalBsmtSF     1.979164
# 1stFlrSF        1.539692
# GrLivArea       1.455564
# WoodDeckSF      1.334388
# BsmtUnfSF       0.900308
# GarageArea      0.838422
# 2ndFlrSF        0.773655

# %% [markdown]
# Transform all the columns where the skew is greater than 0.75, excluding "SalePrice".

# %%
# OPTIONAL: Let's look at what happens to one of these features, when we apply np.log1p visually.

field = "BsmtFinSF1"
fig, (ax_before, ax_after) = plt.subplots(1, 2, figsize=(10, 5))
train[field].hist(ax=ax_before)
train[field].apply(np.log1p).hist(ax=ax_after)
ax_before.set(title='before np.log1p', ylabel='frequency', xlabel='value')
ax_after.set(title='after np.log1p', ylabel='frequency', xlabel='value')
fig.suptitle('Field "{}"'.format(field));
# a little bit better

# %%
# Mute the setting wtih a copy warnings
pd.options.mode.chained_assignment = None

for col in skew_cols.index.tolist():
    if col == "SalePrice":
        continue
    train[col] = np.log1p(train[col])
    test[col]  = test[col].apply(np.log1p)  # same thing

# %% [markdown]
# Separate features from predictor.

# %%
feature_cols = [x for x in train.columns if x != 'SalePrice']
X_train = train[feature_cols]
y_train = train['SalePrice']

X_test  = test[feature_cols]
y_test  = test['SalePrice']

# %% [markdown]
# ## Question 5
#
# * Write a function **`rmse`** that takes in truth and prediction values and returns the root-mean-squared error. Use sklearn's `mean_squared_error`.

# %%
from sklearn.metrics import mean_squared_error


def rmse(ytrue, ypredicted):
    return np.sqrt(mean_squared_error(ytrue, ypredicted))

# %% [markdown]
# * Fit a basic linear regression model
# * print the root-mean-squared error for this model
# * plot the predicted vs actual sale price based on the model.

# %%
from sklearn.linear_model import LinearRegression

linearRegression = LinearRegression().fit(X_train, y_train)

linearRegression_rmse = rmse(y_test, linearRegression.predict(X_test))

print(linearRegression_rmse)
# Out:
# 306369.68342319207

# %%
f = plt.figure(figsize=(6,6))
ax = plt.axes()

ax.plot(y_test, linearRegression.predict(X_test), 
         marker='o', ls='', ms=3.0)

lim = (0, y_test.max())

ax.set(xlabel='Actual Price', 
       ylabel='Predicted Price', 
       xlim=lim,
       ylim=lim,
       title='Linear Regression Results');

# %% [markdown]
# ## Question 6
#
# Ridge regression uses L2 normalization to reduce the magnitude of the coefficients. This can be helpful in situations where there is high variance. The regularization functions in Scikit-learn each contain versions that have cross-validation built in.
#
# * Fit a regular (non-cross validated) Ridge model to a range of $\alpha$ values and plot the RMSE using the cross validated error function you created above.
# * Use $$[0.005, 0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 80]$$ as the range of alphas.
# * Then repeat the fitting of the Ridge models using the range of $\alpha$ values from the prior section. Compare the results.

# %% [markdown]
# Now for the `RidgeCV` method. It's not possible to get the alpha values for the models that weren't selected, unfortunately. The resulting error values and $\alpha$ values are very similar to those obtained above.

# %%
from sklearn.linear_model import RidgeCV

alphas = [0.005, 0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 80]

ridgeCV = RidgeCV(alphas=alphas, 
                  cv=4).fit(X_train, y_train)

ridgeCV_rmse = rmse(y_test, ridgeCV.predict(X_test))

print(ridgeCV.alpha_, ridgeCV_rmse)
# Out:
# 15.0 32169.17620567245

# %% [markdown]
# ## Question 7
#
#
# Much like the `RidgeCV` function, there is also a `LassoCV` function that uses an L1 regularization function and cross-validation. L1 regularization will selectively shrink some coefficients, effectively performing feature elimination.
#
# The `LassoCV` function does not allow the scoring function to be set. However, the custom error function (`rmse`) created above can be used to evaluate the error on the final model.
#
# Similarly, there is also an elastic net function with cross validation, `ElasticNetCV`, which is a combination of L2 and L1 regularization.
#
# * Fit a Lasso model using cross validation and determine the optimum value for $\alpha$ and the RMSE using the function created above. Note that the magnitude of $\alpha$ may be different from the Ridge model.
# * Repeat this with the Elastic net model.
# * Compare the results via table and/or plot.
#
# Use the following alphas:
# `[1e-5, 5e-5, 0.0001, 0.0005]`

# %%
from sklearn.linear_model import LassoCV

alphas2 = np.array([1e-5, 5e-5, 0.0001, 0.0005])

lassoCV = LassoCV(alphas=alphas2,
                  max_iter=5e4,
                  cv=3).fit(X_train, y_train)

lassoCV_rmse = rmse(y_test, lassoCV.predict(X_test))

print(lassoCV.alpha_, lassoCV_rmse)  # Lasso is slower
# Out:
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94004560587.11606, tolerance: 387053725.5878631
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93994612976.76245, tolerance: 387053725.5878631
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93994520747.7372, tolerance: 387053725.5878631
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93994521388.9431, tolerance: 387053725.5878631
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107413893152.14777, tolerance: 391106099.75311756
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107413075413.28725, tolerance: 391106099.75311756
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107413357958.62837, tolerance: 391106099.75311756
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107412831071.60425, tolerance: 391106099.75311756
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120196147330.29025, tolerance: 442399396.3673559
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117863439223.81677, tolerance: 442399396.3673559
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117192989267.98349, tolerance: 442399396.3673559
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117002595054.38033, tolerance: 442399396.3673559
#   model = cd_fast.enet_coordinate_descent_gram(
# 0.0005 39257.393991449186
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.008e+11, tolerance: 6.103e+08
#   model = cd_fast.enet_coordinate_descent(

# %%
print(lassoCV.alpha_, lassoCV_rmse)
# Out:
# 0.0005 39257.393991449186

# %% [markdown]
# We can determine how many of these features remain non-zero.

# %%
print('Of {} coefficients, {} are non-zero with Lasso.'.format(len(lassoCV.coef_), 
                                                               len(lassoCV.coef_.nonzero()[0])))
# Out:
# Of 294 coefficients, 273 are non-zero with Lasso.

# %% [markdown]
# Now try the elastic net, with the same alphas as in Lasso, and l1_ratios between 0.1 and 0.9

# %%
from sklearn.linear_model import ElasticNetCV

l1_ratios = np.linspace(0.1, 0.9, 9)

elasticNetCV = ElasticNetCV(alphas=alphas2, 
                            l1_ratio=l1_ratios,
                            max_iter=1e4).fit(X_train, y_train)
elasticNetCV_rmse = rmse(y_test, elasticNetCV.predict(X_test))

print(elasticNetCV.alpha_, elasticNetCV.l1_ratio_, elasticNetCV_rmse)
# Out:
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100160190520.01189, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167868205508.48645, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164350387941.3733, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162528161728.96988, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19052170001.08307, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140574092723.23505, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137196981947.59213, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134671321573.28369, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54792800784.625916, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 145428933958.92538, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143991180770.3865, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143254030506.42126, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46990327459.23413, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 181066000304.20294, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175377570375.60468, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176173764773.751, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18476923918.516876, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157217089079.48358, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 154430356360.0011, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152520064595.9045, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116709810664.69617, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167136354896.67126, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161487419933.2374, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162349452368.37628, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32318533367.5495, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 139801747918.84875, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136436135346.00394, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134534657378.242, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82443202077.17432, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 145121450661.55093, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143338957072.762, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143128546310.29132, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78586864053.20755, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 180138867604.03323, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 174811028187.7382, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176011212530.94608, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54524535717.56262, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 156483163628.76968, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153636181407.42856, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152385946302.99817, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 124290628382.02658, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 166399258362.72223, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162765289088.4014, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162153487012.91187, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74890054281.49716, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138996664556.76877, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135172496294.56207, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134373451950.25491, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91905820085.01218, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144807276704.09708, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141924355900.3452, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142998997664.57327, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91538575608.61699, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 179433796091.62717, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173467571828.74677, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175831419009.18658, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52913377735.95972, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 155703520464.89478, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152514795694.81427, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152234752659.41058, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142698539365.37186, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 165540844426.31488, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162715485974.61975, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161931683465.48663, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78054852141.07181, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138062641567.4638, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132405085786.07066, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134163857296.66763, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112417507360.7597, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144399770330.6868, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141653855127.97028, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142899840793.86288, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132467112135.02834, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 178483975579.0618, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 174040428939.30508, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175618822052.77075, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77522811363.78418, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 154763849014.61783, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 150884407625.53268, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152055511740.10217, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 149820320808.6462, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164346945998.0091, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162424085249.5418, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161662097464.60803, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113116488616.55261, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137128920206.08891, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133666241750.3679, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133886416158.46559, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135825254524.9404, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143806105048.6065, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142502173680.54074, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142795026654.73785, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 168167857850.216, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176990491401.66028, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173842635548.1477, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175343558216.64502, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140977247875.9704, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153847495001.82224, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 150108811043.48038, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151840366067.38412, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157879737883.3965, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 163110809710.49408, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161330788367.18677, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161839632138.1511, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130890384906.10287, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135982096529.81416, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133479917542.77805, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133582905688.70915, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141093181535.10822, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142791790922.38528, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141814533012.62515, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142570744735.14108, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 174115296348.54413, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173858151369.391, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 172822929036.16428, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175420864491.80914, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 145787119857.2491, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152810044890.45264, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 150553392320.6227, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151589448908.1332, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162052070110.692, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 162087751110.6248, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 159685610030.77264, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161934979651.73602, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140048770386.6477, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135298873428.15674, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133504622268.08243, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133300794164.44646, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142877388311.8541, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141871637096.88834, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140156764561.50317, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142140759991.53555, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 177289904141.3529, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 171538807012.98984, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 171553240285.1425, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175553040282.2864, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152430470034.16672, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152357111335.80753, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151018354072.1164, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151763621510.0211, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 159557492111.62308, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 160754707544.36926, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 158923581795.42282, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161753910248.55228, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 139073962970.78326, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133936563128.21945, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132855856587.25627, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132815865423.77397, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144235019593.11612, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142393509725.23502, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140974018571.93207, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142171345892.58475, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 179645310235.58304, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173767187687.13013, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 168615227128.06607, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175379694571.71558, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 155726111268.922, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 149332881174.52872, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 149415597710.38464, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151715018415.75208, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157428513115.24277, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157764478242.4373, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 156948396960.64243, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161267915202.41168, tolerance: 487372561.3038374
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136163664528.82759, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132547073343.24245, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 131638302032.67508, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130983082531.47939, tolerance: 465192498.4087122
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143997912656.7965, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142598199043.5824, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142214994287.95044, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142042143490.08633, tolerance: 464569448.3765248
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 178215484695.75696, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175133822861.2615, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 174320032061.20935, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 174909698135.07776, tolerance: 534955063.02047503
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 154028173019.05197, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151216771436.00696, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 150623935886.19754, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151224892733.0663, tolerance: 488440735.7074999
#   model = cd_fast.enet_coordinate_descent_gram(
# 0.0005 0.1 35001.23429607458
# D:\Computer science\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.216e+10, tolerance: 6.103e+08
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# Comparing the RMSE calculation from all models is easiest in a table.

# %%
rmse_vals = [linearRegression_rmse, ridgeCV_rmse, lassoCV_rmse, elasticNetCV_rmse]

labels = ['Linear', 'Ridge', 'Lasso', 'ElasticNet']

rmse_df = pd.Series(rmse_vals, index=labels).to_frame()
rmse_df.rename(columns={0: 'RMSE'}, inplace=1)
rmse_df
# Out:
#                      RMSE
# Linear      306369.683423
# Ridge        32169.176206
# Lasso        39257.393991
# ElasticNet   35001.234296

# %% [markdown]
# We can also make a plot of actual vs predicted housing prices as before.

# %%
f = plt.figure(figsize=(6,6))
ax = plt.axes()

labels = ['Ridge', 'Lasso', 'ElasticNet']

models = [ridgeCV, lassoCV, elasticNetCV]

for mod, lab in zip(models, labels):
    ax.plot(y_test, mod.predict(X_test), 
             marker='o', ls='', ms=3.0, label=lab)


leg = plt.legend(frameon=True)
leg.get_frame().set_edgecolor('black')
leg.get_frame().set_linewidth(1.0)

ax.set(xlabel='Actual Price', 
       ylabel='Predicted Price', 
       title='Linear Regression Results');

# %% [markdown]
# ## Question 8
#
# Let's explore Stochastic gradient descent in this exercise.
# Recall that Linear models in general are sensitive to scaling.
# However, SGD is *very* sensitive to scaling.
# Moreover, a high value of learning rate can cause the algorithm to diverge, whereas a too low value may take too long to converge.
#
# * Fit a stochastic gradient descent model without a regularization penalty (the relevant parameter is `penalty`).
# * Now fit stochastic gradient descent models with each of the three penalties (L2, L1, Elastic Net) using the parameter values determined by cross validation above.
# * Do not scale the data before fitting the model.
# * Compare the results to those obtained without using stochastic gradient descent.

# %%
# Import SGDRegressor and prepare the parameters

from sklearn.linear_model import SGDRegressor

model_parameters_dict = {
    'Linear': {'penalty': 'none'},
    'Lasso': {'penalty': 'l2',
           'alpha': lassoCV.alpha_},
    'Ridge': {'penalty': 'l1',
           'alpha': ridgeCV_rmse},
    'ElasticNet': {'penalty': 'elasticnet', 
                   'alpha': elasticNetCV.alpha_,
                   'l1_ratio': elasticNetCV.l1_ratio_}
}

new_rmses = {}
for modellabel, parameters in model_parameters_dict.items():
    # following notation passes the dict items as arguments
    SGD = SGDRegressor(**parameters)
    SGD.fit(X_train, y_train)
    new_rmses[modellabel] = rmse(y_test, SGD.predict(X_test))

rmse_df['RMSE-SGD'] = pd.Series(new_rmses)
rmse_df
# Out:
#                      RMSE      RMSE-SGD
# Linear      306369.683423  1.437151e+16
# Ridge        32169.176206  2.743180e+15
# Lasso        39257.393991  2.851385e+15
# ElasticNet   35001.234296  3.166354e+15

# %% [markdown]
# Notice how high the error values are! The algorithm is diverging. This can be due to scaling and/or learning rate being too high. Let's adjust the learning rate and see what happens.
#
# * Pass in `eta0=1e-7` when creating the instance of `SGDClassifier`.
# * Re-compute the errors for all the penalties and compare.

# %%
# Import SGDRegressor and prepare the parameters

from sklearn.linear_model import SGDRegressor

model_parameters_dict = {
    'Linear': {'penalty': 'none'},
    'Lasso': {'penalty': 'l2',
           'alpha': lassoCV.alpha_},
    'Ridge': {'penalty': 'l1',
           'alpha': ridgeCV_rmse},
    'ElasticNet': {'penalty': 'elasticnet', 
                   'alpha': elasticNetCV.alpha_,
                   'l1_ratio': elasticNetCV.l1_ratio_}
}

new_rmses = {}
for modellabel, parameters in model_parameters_dict.items():
    # following notation passes the dict items as arguments
    SGD = SGDRegressor(eta0=1e-7, **parameters)
    SGD.fit(X_train, y_train)
    new_rmses[modellabel] = rmse(y_test, SGD.predict(X_test))

rmse_df['RMSE-SGD-learningrate'] = pd.Series(new_rmses)
rmse_df
# Out:
#                      RMSE      RMSE-SGD  RMSE-SGD-learningrate
# Linear      306369.683423  1.437151e+16           76371.747928
# Ridge        32169.176206  2.743180e+15           73869.316359
# Lasso        39257.393991  2.851385e+15           74952.629668
# ElasticNet   35001.234296  3.166354e+15           74262.729249

# %% [markdown]
# Now let's scale our training data and try again.
#
# * Fit a `MinMaxScaler` to `X_train` create a variable `X_train_scaled`.
# * Using the scaler, transform `X_test` and create a variable `X_test_scaled`.
# * Apply the same versions of SGD to them and compare the results. Don't pass in a eta0 this time.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

new_rmses = {}
for modellabel, parameters in model_parameters_dict.items():
    # following notation passes the dict items as arguments
    SGD = SGDRegressor(**parameters)
    SGD.fit(X_train_scaled, y_train)
    new_rmses[modellabel] = rmse(y_test, SGD.predict(X_test_scaled))

rmse_df['RMSE-SGD-scaled'] = pd.Series(new_rmses)
rmse_df
# Out:
#                      RMSE      RMSE-SGD  RMSE-SGD-learningrate  \
# Linear      306369.683423  1.437151e+16           76371.747928
# Ridge        32169.176206  2.743180e+15           73869.316359
# Lasso        39257.393991  2.851385e+15           74952.629668
# ElasticNet   35001.234296  3.166354e+15           74262.729249
#
#             RMSE-SGD-scaled
# Linear         32960.835436
# Ridge          77762.664200
# Lasso          32719.705596
# ElasticNet     32771.294566

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

new_rmses = {}
for modellabel, parameters in model_parameters_dict.items():
    # following notation passes the dict items as arguments
    SGD = SGDRegressor(**parameters)
    SGD.fit(X_train_scaled, y_train)
    new_rmses[modellabel] = rmse(y_test, SGD.predict(X_test_scaled))

rmse_df['RMSE-SGD-scaled'] = pd.Series(new_rmses)
rmse_df
# Out:
#                      RMSE      RMSE-SGD  RMSE-SGD-learningrate  \
# Linear      306369.683423  1.437151e+16           76371.747928
# Ridge        32169.176206  2.743180e+15           73869.316359
# Lasso        39257.393991  2.851385e+15           74952.629668
# ElasticNet   35001.234296  3.166354e+15           74262.729249
#
#             RMSE-SGD-scaled
# Linear         32826.626332
# Ridge          77752.576956
# Lasso          32841.259686
# ElasticNet     32878.422376

# %% [markdown]
# ---
# ### Machine Learning Foundation (C) 2020 IBM Corporation
